# %% [markdown]
# # **Learning Pandas**
#
# **Loading a dataset into pandas**

# %%
import pandas as pd

df = pd.read_csv("pokemon_data.csv")


# This loads the first five rows.
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# This loads the last five rows.
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# **Reading Data in Pandas**

# %%
# To read the column headers
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# To read each column seperately, use df['column_name']
df["Name"][0:7]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# 6                Charizard
# Name: Name, dtype: object

# %%
# To read multiple columns, use df[["column 1", "column 2", etc...]]
df[["Name", "Attack"]][0:11]
# Out:
#                          Name  Attack
# 0                   Bulbasaur      49
# 1                     Ivysaur      62
# 2                    Venusaur      82
# 3       VenusaurMega Venusaur     100
# 4                  Charmander      52
# 5                  Charmeleon      64
# 6                   Charizard      84
# 7   CharizardMega Charizard X     130
# 8   CharizardMega Charizard Y     104
# 9                    Squirtle      48
# 10                  Wartortle      63

# %%
# To read each row
df.iloc[2]
# Out:
# #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object

# %%
# To read multiple rows
df.iloc[0: 5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# To get rows based on conditionals, we could use the loc function.
df.loc[df["Attack"] > 50]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# 5      5             Charmeleon     Fire     NaN  58      64       58
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# 5         80       65     80           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [630 rows x 12 columns]

# %% [markdown]
# **Describing and Sorting Data in Pandas**

# %%
# To get a summary of our dataset (i.e. mean, std dev, etc...)
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# To sort dataset by a specific column
df.sort_values("Attack", ascending=False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 163      154      100    130           1       True
# 232       40      105     75           2      False
# 424      150       90     90           3       True
# 426      180      100    115           3       True
# 429      180       20    150           3       True
# ..       ...      ...    ...         ...        ...
# 139       15       20     80           1      False
# 261       75      135     55           2      False
# 230       10      230      5           2      False
# 121       35      105     50           1      False
# 488       15       65     30           4      False
#
# [800 rows x 12 columns]

# %% [markdown]
# **Manipulating Data**

# %%
# We can insert a column into our dataframe.
df["Total Attack"] = df["Attack"] + df["Sp. Atk"]
df["Total Defense"] = df["Defense"] + df["Sp. Def"]
df.head(5)
# Out:
#    #  Attack  Defense  Generation  HP  Legendary                   Name  \
# 0  1      49       49           1  45      False              Bulbasaur
# 1  2      62       63           1  60      False                Ivysaur
# 2  3      82       83           1  80      False               Venusaur
# 3  3     100      123           1  80      False  VenusaurMega Venusaur
# 4  4      52       43           1  39      False             Charmander
#
#    Sp. Atk  Sp. Def  Speed Type 1  Type 2  Total Attack  Total Defense
# 0       65       65     45  Grass  Poison           114            114
# 1       80       80     60  Grass  Poison           142            143
# 2      100      100     80  Grass  Poison           182            183
# 3      122      120     80  Grass  Poison           222            243
# 4       60       50     65   Fire     NaN           112             93

# %%
# We can also change the order of the columns by using reindex
df = df.reindex(sorted(df.columns), axis=1)
df.head()
# Out:
#    #  Attack  Defense  Generation  HP  Legendary                   Name  \
# 0  1      49       49           1  45      False              Bulbasaur
# 1  2      62       63           1  60      False                Ivysaur
# 2  3      82       83           1  80      False               Venusaur
# 3  3     100      123           1  80      False  VenusaurMega Venusaur
# 4  4      52       43           1  39      False             Charmander
#
#    Sp. Atk  Sp. Def  Speed  Total Attack  Total Defense Type 1  Type 2
# 0       65       65     45           114            114  Grass  Poison
# 1       80       80     60           142            143  Grass  Poison
# 2      100      100     80           182            183  Grass  Poison
# 3      122      120     80           222            243  Grass  Poison
# 4       60       50     65           112             93   Fire     NaN

# %% [markdown]
# **Saving a Dataset**

# %%
# This saves the dataframe to a CSV file with the index column removed.
df.to_csv("new_pokemon_data.csv", index=False)

# %% [markdown]
# **Filtering Dataset**

# %%
# We can create a filtering condition using loc function and assign it to a new dataframe.
new_df = df.loc[(df["Attack"] > 50) | (df["Defense"] > 60)]
new_df.head()
# Out:
#    #  Attack  Defense  Generation  HP  Legendary                   Name  \
# 1  2      62       63           1  60      False                Ivysaur
# 2  3      82       83           1  80      False               Venusaur
# 3  3     100      123           1  80      False  VenusaurMega Venusaur
# 4  4      52       43           1  39      False             Charmander
# 5  5      64       58           1  58      False             Charmeleon
#
#    Sp. Atk  Sp. Def  Speed  Total Attack  Total Defense Type 1  Type 2
# 1       80       80     60           142            143  Grass  Poison
# 2      100      100     80           182            183  Grass  Poison
# 3      122      120     80           222            243  Grass  Poison
# 4       60       50     65           112             93   Fire     NaN
# 5       80       65     80           144            123   Fire     NaN

# %%
# We can also run conditionals to manipulate data in different columns. Here I'm asking if the pokemon has an attack greater than 50, then create a column "Strong" for that pokemon and assign it True
new_df.loc[df["Attack"] > 50, "Strong?"] = True
new_df
# Out:
#        #  Attack  Defense  Generation  HP  Legendary                   Name  \
# 1      2      62       63           1  60      False                Ivysaur
# 2      3      82       83           1  80      False               Venusaur
# 3      3     100      123           1  80      False  VenusaurMega Venusaur
# 4      4      52       43           1  39      False             Charmander
# 5      5      64       58           1  58      False             Charmeleon
# ..   ...     ...      ...         ...  ..        ...                    ...
# 795  719     100      150           6  50       True                Diancie
# 796  719     160      110           6  50       True    DiancieMega Diancie
# 797  720     110       60           6  80       True    HoopaHoopa Confined
# 798  720     160       60           6  80       True     HoopaHoopa Unbound
# 799  721     110      120           6  80       True              Volcanion
#
#      Sp. Atk  Sp. Def  Speed  Total Attack  Total Defense   Type 1  Type 2  \
# 1         80       80     60           142            143    Grass  Poison
# 2        100      100     80           182            183    Grass  Poison
# 3        122      120     80           222            243    Grass  Poison
# 4         60       50     65           112             93     Fire     NaN
# 5         80       65     80           144            123     Fire     NaN
# ..       ...      ...    ...           ...            ...      ...     ...
# 795      100      150     50           200            300     Rock   Fairy
# 796      160      110    110           320            220     Rock   Fairy
# 797      150      130     70           260            190  Psychic   Ghost
# 798      170      130     80           330            190  Psychic    Dark
# 799      130       90     70           240            210     Fire   Water
#
#     Strong Strong?
# 1     True    True
# 2     True    True
# 3     True    True
# 4     True    True
# 5     True    True
# ..     ...     ...
# 795   True    True
# 796   True    True
# 797   True    True
# 798   True    True
# 799   True    True
#
# [674 rows x 16 columns]

# %% [markdown]
# **Aggregate Statistics**

# %%
df.groupby("Type 1").mean().sort_values("Attack", ascending=False)
# Out:
# <ipython-input-68-65d777318575>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Type 1").mean().sort_values("Attack", ascending=False)
#                    #      Attack     Defense  Generation         HP  \
# Type 1
# Dragon    474.375000  112.125000   86.375000    3.875000  83.312500
# Fighting  363.851852   96.777778   65.925926    3.370370  69.851852
# Ground    356.281250   95.750000   84.843750    3.156250  73.781250
# Rock      392.727273   92.863636  100.795455    3.454545  65.363636
# Steel     442.851852   92.703704  126.370370    3.851852  65.222222
# Dark      461.354839   88.387097   70.225806    4.032258  66.806452
# Fire      327.403846   84.769231   67.769231    3.211538  69.903846
# Flying    677.750000   78.750000   66.250000    5.500000  70.750000
# Poison    251.785714   74.678571   68.821429    2.535714  67.250000
# Water     303.089286   74.151786   72.946429    2.857143  72.062500
# Ghost     486.500000   73.781250   81.187500    4.187500  64.437500
# Normal    319.173469   73.469388   59.846939    3.051020  77.275510
# Grass     344.871429   73.214286   70.800000    3.357143  67.271429
# Ice       423.541667   72.750000   71.416667    3.541667  72.000000
# Psychic   380.807018   71.456140   67.684211    3.385965  70.631579
# Bug       334.492754   70.971014   70.724638    3.217391  56.884058
# Electric  363.500000   69.090909   66.295455    3.272727  59.795455
# Fairy     449.529412   61.529412   65.705882    4.117647  74.117647
#
#           Legendary    Sp. Atk    Sp. Def       Speed  Total Attack  \
# Type 1
# Dragon     0.375000  96.843750  88.843750   83.031250    208.968750
# Fighting   0.000000  53.111111  64.703704   66.074074    149.888889
# Ground     0.125000  56.468750  62.750000   63.906250    152.218750
# Rock       0.090909  63.340909  75.477273   55.909091    156.204545
